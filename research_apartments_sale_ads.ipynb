# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><code>ceiling_height</code></a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><code>floors_total</code></a></span></li><li><span><a href="#living_area" data-toc-modified-id="living_area-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><code>living_area</code></a></span></li><li><span><a href="#is_apartment" data-toc-modified-id="is_apartment-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span><code>is_apartment</code></a></span></li><li><span><a href="#kitchen_area" data-toc-modified-id="kitchen_area-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span><code>kitchen_area</code></a></span></li><li><span><a href="#balcony" data-toc-modified-id="balcony-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span><code>balcony</code></a></span></li><li><span><a href="#locality_name" data-toc-modified-id="locality_name-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span><code>locality_name</code></a></span></li><li><span><a href="#airports_nearest,-cityCenters_nearest,-parks_nearest,-ponds_nearest,-days_exposition" data-toc-modified-id="airports_nearest,-cityCenters_nearest,-parks_nearest,-ponds_nearest,-days_exposition-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span><code>airports_nearest</code>, <code>cityCenters_nearest</code>, <code>parks_nearest</code>, <code>ponds_nearest</code>, <code>days_exposition</code></a></span></li><li><span><a href="#parks_around3000,-ponds_around3000" data-toc-modified-id="parks_around3000,-ponds_around3000-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span><code>parks_around3000</code>, <code>ponds_around3000</code></a></span></li><li><span><a href="#first_day_exposition" data-toc-modified-id="first_day_exposition-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span><code>first_day_exposition</code></a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Добавляем-цену-квадратного-метра" data-toc-modified-id="Добавляем-цену-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Добавляем цену квадратного метра</a></span></li><li><span><a href="#Добавляем-день-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="Добавляем-день-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавляем день недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Добавляем-этаж-квартиры;-варианты-—-первый,-последний,-другой" data-toc-modified-id="Добавляем-этаж-квартиры;-варианты-—-первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Добавляем этаж квартиры; варианты — первый, последний, другой</a></span></li><li><span><a href="#Добавляем-соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Добавляем-соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Добавляем соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Построим-гистограммы-для-каждого-параметра" data-toc-modified-id="Изучим-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Построим-гистограммы-для-каждого-параметра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра</a></span><ul class="toc-item"><li><span><a href="#Изучаем-площадь" data-toc-modified-id="Изучаем-площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Изучаем площадь</a></span></li><li><span><a href="#Вывод:-Площадь" data-toc-modified-id="Вывод:-Площадь-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Вывод: Площадь</a></span></li><li><span><a href="#Изучаем-цену" data-toc-modified-id="Изучаем-цену-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Изучаем цену</a></span></li><li><span><a href="#Вывод:-Цена" data-toc-modified-id="Вывод:-Цена-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Вывод: Цена</a></span></li><li><span><a href="#Изучаем-число-комнат" data-toc-modified-id="Изучаем-число-комнат-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Изучаем число комнат</a></span></li><li><span><a href="#Вывод:-комнаты" data-toc-modified-id="Вывод:-комнаты-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Вывод: комнаты</a></span><ul class="toc-item"><li><span><a href="#Изучаем-высоту-потолков" data-toc-modified-id="Изучаем-высоту-потолков-4.1.6.1"><span class="toc-item-num">4.1.6.1&nbsp;&nbsp;</span>Изучаем высоту потолков</a></span></li></ul></li><li><span><a href="#Вывод:-Высота-потолков" data-toc-modified-id="Вывод:-Высота-потолков-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Вывод: Высота потолков</a></span></li></ul></li><li><span><a href="#Задача:-Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Задача:-Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Задача: Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Задача:-Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Задача:-Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Задача: Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span><ul class="toc-item"><li><span><a href="#Аномалии-в-total_area" data-toc-modified-id="Аномалии-в-total_area-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Аномалии в <code>total_area</code></a></span></li><li><span><a href="#Аномалии-в-last_price" data-toc-modified-id="Аномалии-в-last_price-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Аномалии в <code>last_price</code></a></span></li><li><span><a href="#Аномалии-в-ceiling_height" data-toc-modified-id="Аномалии-в-ceiling_height-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Аномалии в <code>ceiling_height</code></a></span></li></ul></li><li><span><a href="#Задача:-Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Задача:-Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Задача: Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади" data-toc-modified-id="Зависимость-цены-от-площади-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость цены от площади</a></span></li><li><span><a href="#Зависимость-цены-от-количества-комнат" data-toc-modified-id="Зависимость-цены-от-количества-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость цены от количества комнат</a></span></li><li><span><a href="#Зависимость-цены-от-удалённости-от-центра" data-toc-modified-id="Зависимость-цены-от-удалённости-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость цены от удалённости от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом." data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Зависимость-цены-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость цены от даты размещения: дня недели, месяца и года.</a></span></li></ul></li><li><span><a href="#Задача:-Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Задача:-Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Задача: Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Задача:-Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Задача:-Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Задача: Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (<code>locality_name</code>). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.</a></span></li><li><span><a href="#Задание:-Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?" data-toc-modified-id="Задание:-Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Задание: Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?</a></span><ul class="toc-item"><li><span><a href="#Изучим-площадь" data-toc-modified-id="Изучим-площадь-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Изучим площадь</a></span></li><li><span><a href="#Изучим-цену" data-toc-modified-id="Изучим-цену-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Изучим цену</a></span></li><li><span><a href="#Изучим-количество-комнат" data-toc-modified-id="Изучим-количество-комнат-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Изучим количество комнат</a></span></li><li><span><a href="#Изучим-высоту-потолков" data-toc-modified-id="Изучим-высоту-потолков-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Изучим высоту потолков</a></span></li><li><span><a href="#Оценим,-как-число-комнат-влияет-на-стоимость-квартиры" data-toc-modified-id="Оценим,-как-число-комнат-влияет-на-стоимость-квартиры-4.7.5"><span class="toc-item-num">4.7.5&nbsp;&nbsp;</span>Оценим, как число комнат влияет на стоимость квартиры</a></span></li><li><span><a href="#Оценим,-как-этаж-влияет-на-стоимость-квартиры" data-toc-modified-id="Оценим,-как-этаж-влияет-на-стоимость-квартиры-4.7.6"><span class="toc-item-num">4.7.6&nbsp;&nbsp;</span>Оценим, как этаж влияет на стоимость квартиры</a></span></li><li><span><a href="#Оценим,-как-удалённость-от-центра-влияет-на-стоимость-квартиры" data-toc-modified-id="Оценим,-как-удалённость-от-центра-влияет-на-стоимость-квартиры-4.7.7"><span class="toc-item-num">4.7.7&nbsp;&nbsp;</span>Оценим, как удалённость от центра влияет на стоимость квартиры</a></span></li><li><span><a href="#Оценим,-как-дата-размещения-влияет-на-стоимость-квартиры" data-toc-modified-id="Оценим,-как-дата-размещения-влияет-на-стоимость-квартиры-4.7.8"><span class="toc-item-num">4.7.8&nbsp;&nbsp;</span>Оценим, как дата размещения влияет на стоимость квартиры</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описание данных**
#
# `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# `balcony` — число балконов
# `ceiling_height` — высота потолков (м)
# `cityCenters_nearest` — расстояние до центра города (м)
# `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# `first_day_exposition` — дата публикации
# `floor` — этаж
# `floors_total` — всего этажей в доме
# `is_apartment` — апартаменты (булев тип)
# `kitchen_area` — площадь кухни в квадратных метрах (м²)
# `last_price` — цена на момент снятия с публикации
# `living_area` — жилая площадь в квадратных метрах (м²)
# `locality_name` — название населённого пункта
# `open_plan` — свободная планировка (булев тип)
# `parks_around3000` — число парков в радиусе 3 км
# `parks_nearest` — расстояние до ближайшего парка (м)
# `ponds_around3000` — число водоёмов в радиусе 3 км
# `ponds_nearest` — расстояние до ближайшего водоёма (м)
# `rooms` — число комнат
# `studio` — квартира-студия (булев тип)
# `total_area` — площадь квартиры в квадратных метрах (м²)
# `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# Введём определение, которым будем пользоваться в течение работы:
#
# **Квартира-студия** — тип квартиры, основным отличием которого является отсутствие внутренних перегородок между кухней и жилыми комнатами или комнатой.

# %% [markdown]
# ## Изучение данных из файла

# %%
# импортируем нужные библиотеки

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# читаем файл и сохраняем его в переменную data

data = pd.read_csv("/datasets/real_estate_data.csv", sep = '\t')

# %%
# делаем первый взгляд на данные

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Вывод
# Названия столбцов уже в snake_case, правки не требуются.
# Количество значений в колонках разное, есть пропуски в столбцах:
# - `ceiling_height`
# - `floors_total`
# - `living_area`
# - `is_apartment`
# - `kitchen_area`
# - `balcony`
# - `locality_name`
# - `airports_nearest`
# - `cityCenters_nearest`
# - `parks_around3000`
# - `parks_nearest`
# - `ponds_around3000`
# - `ponds_nearest`
# - `days_exposition`
#
# Данные 4х типов, потребуются изменения, например, в `floors_total` тип float, а должен быть int, ведь количество этажей не может быть дробным.

# %%
# выводим 5 первых строк

data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для дальнейшей работы нужно обработать пропуски и изменить типы данных.

# %% [markdown]
# ## Предобработка данных

# %%
# столбец с количеством фото для исследования не нужен, можно удалить

data = data.drop(columns=['total_images'])
data.columns
# Out:
# Index(['last_price', 'total_area', 'first_day_exposition', 'rooms',
#        'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Ненужный нам столбец удалён, теперь обрабатываем пропуски, идём прямо по списку.

# %% [markdown]
# ### `ceiling_height`

# %%
# начинаем с высоты потолков, оцениваем количество пропусков

data['ceiling_height'].isna().sum()
# Out:
# 9195

# %% [markdown]
# Довольно большое значение, желательно заполнить.

# %%
# смотрим статистические данные

data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Мы анализируем жилые помещения, поэтому среднее значение высоты потолка в 2.7 метра выглядит нормально.
# Аномальные значения: минимальная высота 1 метр, максимальная 100, это явные выбросы.

# %%
# посмотрим, сколько их

display(data[data['ceiling_height'] == 1].sort_values('ceiling_height'))

data[data['ceiling_height'] == 100].sort_values('ceiling_height')
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 22590   6000000.0        55.0  2018-10-31T00:00:00      2             1.0
#
#        floors_total  living_area  floor is_apartment  studio  ...  \
# 22590          12.0         32.4      7          NaN   False  ...
#
#        kitchen_area  balcony    locality_name airports_nearest  \
# 22590          10.0      NaN  Санкт-Петербург          33053.0
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 22590              14217.0               2.0          293.0               2.0
#
#        ponds_nearest  days_exposition
# 22590          289.0             13.0
#
# [1 rows x 21 columns]
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 22869  15000000.0        25.0  2018-07-25T00:00:00      1           100.0
#
#        floors_total  living_area  floor is_apartment  studio  ...  \
# 22869           5.0         14.0      5         True   False  ...
# ...

# %% [markdown]
# Всего по одному значению, можно так и оставить, а можно и удалить.

# %%
# удаляем эти две строки по индексам

data.drop(labels=[22590, 22869], axis=0, inplace=True)

# %%
# проверяем результат

display(data[data['ceiling_height'] == 1].sort_values('ceiling_height'))

data[data['ceiling_height'] == 100].sort_values('ceiling_height')
# Out:
# Empty DataFrame
# Columns: [last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 21 columns]
# Empty DataFrame
# Columns: [last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Выбросы удалены. Теперь можно подумать о том, как заполнить пропущенные значения.
#
# Строительство - хорошо задокументированная сфера, поэтому можно взять минимальное значение из **Постановления Правительства РФ** от 28 января 2006 г. N 47 "Об утверждении Положения о признании помещения жилым помещением...", где говорится, что:
#
# "Высота (от пола до потолка) комнат и кухни (кухни-столовой) в климатических районах IА, IБ, IГ, IД и IVа должна быть не менее **2,7 м**, а в других климатических районах - не менее 2,5 м."
#
# Заполним пропуски значением 2.7 м.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.7)

# %%
# проверка

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23697 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23697 non-null  float64
#  1   total_area            23697 non-null  float64
#  2   first_day_exposition  23697 non-null  object
#  3   rooms                 23697 non-null  int64
#  4   ceiling_height        23697 non-null  float64
#  5   floors_total          23611 non-null  float64
#  6   living_area           21794 non-null  float64
#  7   floor                 23697 non-null  int64
#  8   is_apartment          2774 non-null   object
#  9   studio                23697 non-null  bool
#  10  open_plan             23697 non-null  bool
#  11  kitchen_area          21419 non-null  float64
#  12  balcony               12179 non-null  float64
#  13  locality_name         23648 non-null  object
#  14  airports_nearest      18155 non-null  float64
# ...

# %% [markdown]
# Пропуски в `ceiling_height` заполнены.

# %% [markdown]
# ### `floors_total`

# %%
# оцениваем ситуацию

data['floors_total'].describe()
# Out:
# count    23611.000000
# mean        10.674008
# std          6.597343
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# В этом столбце выдающееся значение только одно, 60 этаж, скорее всего, это просто 6.

# %%
# считаем пропуски

data['floors_total'].isna().sum()
# Out:
# 86

# %% [markdown]
# Пропусков крайне мало, что понятно, этажность один из самых важных параметров.
# Кроме того, во всех формах подачи объявлений это обязательное поле, что наводит на мысль о проблеме с выгрузкой.
# Подходящих значений для замены нет, да и пропусков столь мало, что просто их удалим, чтобы изменить тип данных.
# Количество этажей вседа целое число.

# %%
# удаляем пропуски

data.dropna(subset=['floors_total'], inplace=True)

# %%
# приводим к типу int

data['floors_total'] = data['floors_total'].astype('int')

# %%
# проверка

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23611 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23611 non-null  float64
#  1   total_area            23611 non-null  float64
#  2   first_day_exposition  23611 non-null  object
#  3   rooms                 23611 non-null  int64
#  4   ceiling_height        23611 non-null  float64
#  5   floors_total          23611 non-null  int64
#  6   living_area           21741 non-null  float64
#  7   floor                 23611 non-null  int64
#  8   is_apartment          2774 non-null   object
#  9   studio                23611 non-null  bool
#  10  open_plan             23611 non-null  bool
#  11  kitchen_area          21380 non-null  float64
#  12  balcony               12132 non-null  float64
#  13  locality_name         23563 non-null  object
#  14  airports_nearest      18079 non-null  float64
# ...

# %% [markdown]
# Пропуски удалены, тип данных изменён.

# %% [markdown]
# ### `living_area`

# %%
# посчитаем количество пропусков

data['living_area'].isna().sum()
# Out:
# 1870

# %% [markdown]
# Пропуски можно заменить медианой по общей площади. Сначала заменим пропуски на нетипичные значения, изменим тип.

# %%
# для удбства округлим и приведём к нужному типу

data['total_area'] = data['total_area'].round().astype('int')

# %%
# заполним пропуски

data['living_area'] = data['living_area'].fillna(-1)

# %%
# функция для замены

def count_living_area(row):
    living_area = row['living_area']
    total_area = row['total_area']
    if living_area == -1:      
        return total_area_to_median[total_area]
    return living_area
 
total_area_to_median = data.groupby('total_area').median()['living_area'].to_dict()    
       
data['living_area'] = data.apply(count_living_area, axis=1)

# %%
# проверяем, есть ли ещё нетипичные значения

len(data.query('living_area == -1'))
# Out:
# 19

# %%
# их очень мало, удалим

data = data[data['living_area'] != -1]

# %%
# проверка изменений

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23592 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23592 non-null  float64
#  1   total_area            23592 non-null  int64
#  2   first_day_exposition  23592 non-null  object
#  3   rooms                 23592 non-null  int64
#  4   ceiling_height        23592 non-null  float64
#  5   floors_total          23592 non-null  int64
#  6   living_area           23592 non-null  float64
#  7   floor                 23592 non-null  int64
#  8   is_apartment          2773 non-null   object
#  9   studio                23592 non-null  bool
#  10  open_plan             23592 non-null  bool
#  11  kitchen_area          21377 non-null  float64
#  12  balcony               12124 non-null  float64
#  13  locality_name         23544 non-null  object
#  14  airports_nearest      18062 non-null  float64
# ...

# %% [markdown]
# ### `is_apartment`

# %%
data['is_apartment'].isna().sum()
# Out:
# 20819

# %% [markdown]
# Тут довольно просто, если зачения нет, то это не апартаменты, поэтому просто заменим все пропуски на False.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
# проверка

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23592 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23592 non-null  float64
#  1   total_area            23592 non-null  int64
#  2   first_day_exposition  23592 non-null  object
#  3   rooms                 23592 non-null  int64
#  4   ceiling_height        23592 non-null  float64
#  5   floors_total          23592 non-null  int64
#  6   living_area           23592 non-null  float64
#  7   floor                 23592 non-null  int64
#  8   is_apartment          23592 non-null  bool
#  9   studio                23592 non-null  bool
#  10  open_plan             23592 non-null  bool
#  11  kitchen_area          21377 non-null  float64
#  12  balcony               12124 non-null  float64
#  13  locality_name         23544 non-null  object
#  14  airports_nearest      18062 non-null  float64
# ...

# %% [markdown]
# Ещё один столбец приведён в порядок.

# %% [markdown]
# ### `kitchen_area`

# %%
# оцениваем значения

data['kitchen_area'].describe()
# Out:
# count    21377.000000
# mean        10.561010
# std          5.898539
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
# количество пропусков

data['kitchen_area'].isna().sum()
# Out:
# 2215

# %%
# количество пропусков в студиях
data[(data['kitchen_area'].isna())]['studio'].sum()
# Out:
# 146

# %% [markdown]
# Логично предполжить, что если площадь кухни не указана, то это, скорее всего, студия.

# %%
data.loc[data["kitchen_area"].isnull(),'studio'] = True

# %%
# заменим у студий пропущенные значения на 0

data["kitchen_area"] = data["kitchen_area"].where(~data["kitchen_area"].isna(), 0)

# %%
# проверка

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23592 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23592 non-null  float64
#  1   total_area            23592 non-null  int64
#  2   first_day_exposition  23592 non-null  object
#  3   rooms                 23592 non-null  int64
#  4   ceiling_height        23592 non-null  float64
#  5   floors_total          23592 non-null  int64
#  6   living_area           23592 non-null  float64
#  7   floor                 23592 non-null  int64
#  8   is_apartment          23592 non-null  bool
#  9   studio                23592 non-null  bool
#  10  open_plan             23592 non-null  bool
#  11  kitchen_area          23592 non-null  float64
#  12  balcony               12124 non-null  float64
#  13  locality_name         23544 non-null  object
#  14  airports_nearest      18062 non-null  float64
# ...

# %% [markdown]
# Пропуски устранены.

# %% [markdown]
# ### `balcony`

# %%
# оценим этим методом, значений в этом столбце всего 6

data['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3706
# 2.0    3657
# 5.0     302
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %%
# считаем пропуски

data['balcony'].isna().sum()
# Out:
# 11468

# %% [markdown]
# Логично предположить, что если данных нет, то и балкона тоже нет, поэтому заполним пропуски нулями.
# И изменим тип на int, т.к. количество балконов всегда целое число.

# %%
data['balcony'] = data['balcony'].fillna(0).astype('int')

# %%
# проверка изменений, пропуски заполнены 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23592 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            23592 non-null  float64
#  1   total_area            23592 non-null  int64
#  2   first_day_exposition  23592 non-null  object
#  3   rooms                 23592 non-null  int64
#  4   ceiling_height        23592 non-null  float64
#  5   floors_total          23592 non-null  int64
#  6   living_area           23592 non-null  float64
#  7   floor                 23592 non-null  int64
#  8   is_apartment          23592 non-null  bool
#  9   studio                23592 non-null  bool
#  10  open_plan             23592 non-null  bool
#  11  kitchen_area          23592 non-null  float64
#  12  balcony               23592 non-null  int64
#  13  locality_name         23544 non-null  object
#  14  airports_nearest      18062 non-null  float64
# ...

# %% [markdown]
# ### `locality_name`

# %%
# первый взгляд

data['locality_name'].value_counts()
# Out:
# Санкт-Петербург                      15631
# посёлок Мурино                         520
# посёлок Шушары                         439
# Всеволожск                             398
# Пушкин                                 369
#                                      ...
# поселок Жилгородок                       1
# деревня Пустынка                         1
# поселок Красносельское                   1
# садовое товарищество Приладожский        1
# деревня Шпаньково                        1
# Name: locality_name, Length: 364, dtype: int64

# %%
# считаем количество населённых пунктов

data['locality_name'].nunique()
# Out:
# 364

# %%
# считаем количство пропусков

data['locality_name'].isna().sum()
# Out:
# 48

# %%
data[data['locality_name'].isna()].sort_values(by='first_day_exposition')
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 4151   17600000.0          90  2014-12-09T00:00:00      2            3.00
# 11248   6300000.0          63  2015-01-16T00:00:00      4            2.70
# 9821    8000000.0          94  2015-01-21T00:00:00      4            3.00
# 7330    5100000.0          63  2015-01-27T00:00:00      3            2.70
# 13223   2919911.0          29  2015-03-12T00:00:00      1            2.75
# 6765    4895892.0          61  2015-03-12T00:00:00      2            2.70
# 21333   5900000.0          58  2015-03-12T00:00:00      3            2.70
# 22933   3176015.0          33  2015-04-22T00:00:00      1            2.70
# 10122   8200000.0          83  2015-06-24T00:00:00      4            2.70
# 22474  24000000.0         128  2015-07-24T00:00:00      4            2.75
# 4670    5500000.0          83  2015-08-14T00:00:00      3            2.70
# 2603    3351765.0          43  2015-09-20T00:00:00      1            2.70
# ...

# %% [markdown]
# **Отсутствие пожалуй, самого важного параметра, места расположения квартиры, это важный артефакт**, о нём лучше сразу сообщить тем, кто делал выгрузку.
# По крайней мере, пропусков всего 48, что очень мало.
# Сортировка по дате выставления показывает, что пропуски есть во всех годах с 2014 по 2018.
# Заполнить их не можем, оставляем как есть, чтобы не скрывать проблему.

# %% [markdown]
# ### `airports_nearest`, `cityCenters_nearest`, `parks_nearest`, `ponds_nearest`, `days_exposition`

# %%
# заменим пропуски на нетипичные значения

data['airports_nearest'] = data['airports_nearest'].fillna(-1)
data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna(-1)
data['parks_nearest'] = data['parks_nearest'].fillna(-1)
data['ponds_nearest'] = data['ponds_nearest'].fillna(-1)
data['days_exposition'] = data['days_exposition'].fillna(-1).astype('int') # попутно изменили тип

# %% [markdown]
# Можно было заменить пропуски в `cityCenters_nearest` с помощью столбца `locality_name` и медианой по нему или средним значением, но есть нюанс. Для совсем небольших населёных пунктов (например, городской посёлок Янино-1) не дано расстояние до центра, т.к. центра там, скорее всего, и нет.
# Поэтому подсвечиваем проблему нетипичными значениями.

# %% [markdown]
# ### `parks_around3000`, `ponds_around3000`

# %% [markdown]
# Как и в ситуации с балконами, будем считать, что если нет данных, то и прудов с парками в указанном радиусе нет. Пропуски оставляем, нулями заполнять не будем, т.к. в дальнейшим эти нули могут дать нам ложную картину, так как корреляция не чувствительна к пропускам. Отсутствие значения — тоже важный сигнал, который не нужно прятать.

# %% [markdown]
# ### `first_day_exposition`

# %%
# изменим тип на datetime без времени, т.к. время не указано

data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')

# %%
# проверка

data['first_day_exposition'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Добавляем цену квадратного метра

# %%
# делим последнюю цену на общий метраж, заодно округлим и изменим тип

data['price_per_meter'] = (data['last_price'] / data['total_area']).round().astype('int')

# %%
# проверим изменение типа

data['price_per_meter'].dtype
# Out:
# dtype('int64')

# %%
# и как выглядит конечный результат

data.head()
# Out:
#    last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 0  13000000.0         108           2019-03-07      3            2.70
# 1   3350000.0          40           2018-12-04      1            2.70
# 2   5196000.0          56           2015-08-20      2            2.70
# 3  64900000.0         159           2015-07-24      3            2.70
# 4  10000000.0         100           2018-06-19      2            3.03
#
#    floors_total  living_area  floor  is_apartment  studio  ...  balcony  \
# 0            16         51.0      8         False   False  ...        0
# 1            11         18.6      1         False   False  ...        2
# 2             5         34.3      4         False   False  ...        0
# 3            14         90.8      9         False    True  ...        0
# 4            14         32.0     13         False   False  ...        0
#
#      locality_name  airports_nearest cityCenters_nearest  parks_around3000  \
# ...

# %% [markdown]
# ### Добавляем день недели, месяц и год публикации объявления

# %%
data['expos_weekday'] = data['first_day_exposition'].dt.weekday
data['expos_month'] = data['first_day_exposition'].dt.month
data['expos_year'] = data['first_day_exposition'].dt.year

# %%
# проверка

data.sample(5)
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 17421  21500000.0          96           2019-02-13      3            2.80
# 6447    5850000.0          59           2017-02-07      2            2.95
# 10985   3850000.0          40           2018-10-09      1            2.60
# 20770  11564288.0         114           2017-10-03      4            2.70
# 6139    3250000.0          36           2015-02-20      1            2.70
#
#        floors_total  living_area  floor  is_apartment  studio  ...  \
# 17421            25         59.5     22         False   False  ...
# 6447              5         34.4      4         False   False  ...
# 10985             9         18.0      4         False   False  ...
# 20770            11         72.1      2         False   False  ...
# 6139              9         18.3      9         False   False  ...
#
#        cityCenters_nearest  parks_around3000  parks_nearest ponds_around3000  \
# ...

# %% [markdown]
# ### Добавляем этаж квартиры; варианты — первый, последний, другой

# %%
# напишем функцию для сортировки по этажам

def floor_category(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
data['floor_category'] = data.apply(floor_category, axis = 1)

# %%
# проверка

data.sample(5)
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 16587   3000000.0          33           2015-07-01      1            2.50
# 13966   5100000.0          72           2018-02-09      3            2.50
# 23529   4450000.0          45           2018-10-10      2            2.50
# 522     3690000.0          53           2015-10-31      2            2.70
# 21335   7100000.0          58           2019-03-04      2            2.66
#
#        floors_total  living_area  floor  is_apartment  studio  ...  \
# 16587             9         18.0      8         False   False  ...
# 13966             5         43.0      1         False    True  ...
# 23529             9         27.7      8         False    True  ...
# 522              25         28.0      9         False   False  ...
# 21335            16         32.5     14         False   False  ...
#
#        parks_around3000  parks_nearest  ponds_around3000 ponds_nearest  \
# ...

# %% [markdown]
# ### Добавляем соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
# заодно округлим до двух значений после запятой

data['living_to_total_ratio'] = round(data['living_area'] / data['total_area'],2)
data['kitchen_to_total_ratio'] = round(data['kitchen_area'] / data['total_area'],2)

# %%
# проверка

data.sample(5)
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 13834   6000000.0          63           2017-02-16      3            2.70
# 5831    3700000.0          43           2017-10-12      2            2.70
# 4552    5850000.0          66           2018-07-21      3            2.70
# 22992   5600000.0          63           2019-04-05      3            2.55
# 14133   8750000.0          90           2016-04-01      3            2.80
#
#        floors_total  living_area  floor  is_apartment  studio  ...  \
# 13834             9         37.8      3         False    True  ...
# 5831              9         28.0      8         False   False  ...
# 4552             15         39.0     12         False   False  ...
# 22992            12         43.0     11         False   False  ...
# 14133             5         61.8      4         False   False  ...
#
#        ponds_around3000  ponds_nearest  days_exposition price_per_meter  \
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра

# %% [markdown]
# #### Изучаем площадь

# %%
# смотрим статистику

data['total_area'].describe()
# Out:
# count    23592.000000
# mean        60.160605
# std         34.778119
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Видны выбросы по миимальному и максимальному значению, но существенного влияния они не оказывают, медиана и среднее вполне адекватны.

# %%
# строим гистограмму

data['total_area'].hist(figsize=(16,4), bins = 30)
# Out:
# <AxesSubplot:>

# %%
# ограничим значение площади, поставим 300

plt.title('Total area < 300')
plt.xlabel('Total area')
plt.ylabel('Amount')

data['total_area'].hist(range = (0,300), figsize=(16,4), bins = 30)
# Out:
# <AxesSubplot:title={'center':'Total area < 300'}, xlabel='Total area', ylabel='Amount'>

# %%
# посмотрим на ящик с усами

data.boxplot(column='total_area', figsize=(5,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Вывод: Площадь

# %% [markdown]
# Большинство квартир имеют площадь от 40 до 60 кв.м, что вполне логично, это однокомнатные и двухкомнатные, самые востребованные и популярные.
# Виден довольно плавный спад предложения, чем больше площадь и комнат, тем меньше таких вариантов.
# Есть весьма выдающиеся значения, как крайне малые, около 12 кв.м., так и около 900, явные выбросы, о них следует сообщать ответственным лицам.

# %% [markdown]
# #### Изучаем цену

# %%
# первым делом статистика

data['last_price'].describe()
# Out:
# count    2.359200e+04
# mean     6.500137e+06
# std      1.067321e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646500e+06
# 75%      6.782500e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].hist(range=(0, 20000000), figsize=(16,3), bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Вывод: Цена

# %% [markdown]
# В целом картина совершенно нормальная, медиана 4,6 млн, средняя цена 6,5 млн. Выбросы есть, ещё избавимся от них.

# %% [markdown]
# #### Изучаем число комнат

# %%
# смотрим статистику

data['rooms'].describe()
# Out:
# count    23592.000000
# mean         2.070066
# std          1.076277
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
# смотрим значения

data['rooms'].value_counts()
# Out:
# 1     8008
# 2     7912
# 3     5794
# 4     1174
# 5      320
# 0      193
# 6      103
# 7       57
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %%
# строим гистограмму

data['rooms'].hist(range=(0,20), figsize=(16,5), bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Вывод: комнаты

# %% [markdown]
# Количество однокомнатных квартир (8008) чуть больше, чем двухкомнатных (7912). Трёхкомнатных (5794) довольно много, а все остальные идут с явным отрывом. Количество студий небольшое (193), этот формат довольно новый. Есть выбросы, 19 комнат, например, это уже какой-то дворец. Хотя это ж Питер :)

# %% [markdown]
# ##### Изучаем высоту потолков

# %%
# смотрим статистику

data['ceiling_height'].describe()
# Out:
# count    23592.000000
# mean         2.739605
# std          0.759820
# min          1.200000
# 25%          2.600000
# 50%          2.700000
# 75%          2.700000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
# считаем количество значений

data['ceiling_height'].nunique()
# Out:
# 180

# %%
# округлим, чтобы уменьшить это число

round(data['ceiling_height'],1).nunique()
# Out:
# 49

# %%
# теперь можно оценить

round(data['ceiling_height'],1).value_counts()
# Out:
# 2.7     10868
# 2.5      3791
# 2.6      3731
# 2.8      2241
# 3.0      1239
# 3.2       406
# 3.1       284
# 2.9       212
# 3.3       181
# 3.5       157
# 3.4       137
# 3.6        72
# 4.0        48
# 3.7        38
# 2.4        38
# 3.8        37
# 3.9        19
# 4.2        14
# 2.0        11
# 27.0        8
# 4.5         7
# 25.0        7
# 4.4         6
# 4.1         5
# 2.3         5
# 8.0         3
# 4.7         2
# 2.2         2
# 32.0        2
# 5.3         2
# 8.3         1
# 4.3         1
# 5.8         1
# 26.0        1
# 1.8         1
# 5.0         1
# 27.5        1
# 6.0         1
# 5.5         1
# 4.6         1
# 4.8         1
# 10.3        1
# 24.0        1
# 14.0        1
# 22.6        1
# 4.9         1
# 5.2         1
# 20.0        1
# 1.2         1
# Name: ceiling_height, dtype: int64

# %%
round(data['ceiling_height'],1).hist(range=(2,5), figsize=(8,5), bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Вывод: Высота потолков

# %% [markdown]
# Самая распространённая высота - 2,7 м, ниже и выше значения встречаются гораздо меньше, всё же стандарты в стоительстве как-никак соблюдаются.

# %% [markdown]
# ### Задача: Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].describe()
# Out:
# count    23592.000000
# mean       156.462233
# std        213.605516
# min         -1.000000
# 25%         22.000000
# 50%         74.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# выводим медиану

data['days_exposition'].median()
# Out:
# 74.0

# %%
# выводим среднее

data['days_exposition'].mean()
# Out:
# 156.46223296032554

# %%
# строим общую гистограмму

data['days_exposition'].hist(figsize=(16,5), bins=50)
# Out:
# <AxesSubplot:>

# %%
# теперь смотрим детальнее

data['days_exposition'].hist(figsize=(16,5), bins=50, range = (1,200))
# Out:
# <AxesSubplot:>

# %%
# странные пики, ещё детальнее

data['days_exposition'].hist(figsize=(16,5), bins=50, range = (1,100))
# Out:
# <AxesSubplot:>

# %%
# таких значений много

data['days_exposition'].value_counts()
# Out:
# -1       3168
#  45       879
#  60       538
#  7        234
#  30       208
#          ...
#  1112       1
#  1080       1
#  1064       1
#  1032       1
#  1391       1
# Name: days_exposition, Length: 1140, dtype: int64

# %% [markdown]
# **Но у этих выбросов есть простое объяснение.** В правилах публикации объявлений Яндекса указаны сроки размещения:
# - до 4,5 млн — 45 дней
# - от 4,5 до 10 млн — 60 дней
# - от 10 млн — 90 дней
#
# Как видим, значения совпадают.

# %%
# и посмотрим на ящик

data.boxplot(column='days_exposition', figsize=(5,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод:**
# По этим данным медиана 74 дня, среднее 156.
# Если предположить, что снятые через 45 дней объявления не были потом опубликованы повтороно, то продажа за такой промежуток времени будет считаться быстрой. А если более 199 дней - длинной.

# %% [markdown]
# ### Задача: Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# **Уже удалены:** значения потолков 1 и 100 м.

# %% [markdown]
# #### Аномалии в `total_area`

# %%
# вспоминаем про аномалии по площади

data.boxplot(column='total_area', figsize=(3,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Нормальные значения в пределах от примерно 15 кв.м и до 120 кв.м. Избавимся от аномальных. Про аномалии подробнее чуть ниже, где про ценовые параметры.

# %%
# создадим новый датафрейм

filtered_data = data.query('total_area >= 15 and total_area <= 120')

# %%
# проверим

filtered_data.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Аномалии в `last_price`

# %%
# на первый взгляд аномалии есть

data.boxplot(column='last_price', figsize=(3,8))
# Out:
# <AxesSubplot:>

# %%
# ещё раз посмотрим статистику

data['last_price'].describe()
# Out:
# count    2.359200e+04
# mean     6.500137e+06
# std      1.067321e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646500e+06
# 75%      6.782500e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
# сделаем срез > 90 млн, объекты дороже нужно рассмотреть детально, сразу отсортируем по цене для удобства и наглядности

data.query('last_price > 90000000').sort_values(by=['last_price'])
# Out:
#         last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 22494   91075000.0         491           2017-05-27      5            4.20
# 12401   91500000.0         495           2017-06-19      7            4.65
# 11329   95000000.0         190           2019-02-10      5            3.00
# 492     95000000.0         216           2017-12-05      4            3.00
# 155     96000000.0         317           2017-07-07      4            3.50
# 16590   98000000.0         155           2017-12-16      3            2.70
# 5631    99000000.0         280           2018-01-19      3            2.70
# 6621    99000000.0         488           2017-04-09      5            2.95
# 21923  115490000.0         235           2017-04-09      5            4.90
# 1188   118000000.0         291           2018-06-01      6            3.82
# 20264  119000000.0         188           2017-07-10      4            6.00
# ...

# %% [markdown]
# **Промежуточный вывод:**
# Как видим, два самых дорогих объекта при пристальном изучении уже **не выглядят подозрительно**. Внушительная площадь (900 и 400 кв.м), 12 и 7 комнат, последние этажи (видимо, пентхаусы), все параметры выглядят вполне реально.
# Для проверки загуглил "самые дорогие квартиры спб", первая ссылка - статья на фонтанке, где читаем: "Самая дорогая квартира в Петербурге выставлена на продажу за **822,9 млн рублей** в новом очень элитном жилом комплексе на Гребном канале". Аж в "очень элитном" доме. Так что квартиры с такими ценами это не случайные выбросы, а суровая реальность.

# %%
# а теперь посмотрим самые доступные варианты

data.query('last_price < 500000').sort_values(by=['last_price'])
# Out:
#        last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 8793      12190.0         109           2019-03-20      2            2.75
# 14911    430000.0          54           2018-06-26      2            2.70
# 17456    430000.0          30           2019-04-22      1            2.70
# 16274    440000.0          40           2018-07-10      1            2.70
# 5698     450000.0          42           2017-07-31      2            2.70
# 9581     450000.0          43           2018-08-31      2            2.70
# 16219    450000.0          38           2018-07-11      2            2.65
# 17676    450000.0          36           2018-02-01      1            2.70
# 18867    470000.0          41           2018-02-11      1            2.70
# 21912    470000.0          37           2018-02-18      1            2.70
# 23484    470000.0          44           2018-07-02      2            2.70
# 16032    480000.0          32           2019-01-06      1            2.70
# ...

# %%
# тут аномалия явно одна, нечто за 12 тыс. руб., удалим

filtered_data = data.query('last_price > 13000')

# %%
# проверим

filtered_data.query('last_price < 13000')
# Out:
# Empty DataFrame
# Columns: [last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, price_per_meter, expos_weekday, expos_month, expos_year, floor_category, living_to_total_ratio, kitchen_to_total_ratio]
# Index: []
#
# [0 rows x 28 columns]

# %%
# отфильтруем выдающиеся значения, создадим новый датафрейм

filtered_data = data.query('last_price > 10000 and last_price <= 11000000')

# %%
# статистика теперь такая

filtered_data['last_price'].describe()
# Out:
# count    2.133600e+04
# mean     4.770691e+06
# std      2.121819e+06
# min      1.219000e+04
# 25%      3.300000e+06
# 50%      4.400000e+06
# 75%      5.950000e+06
# max      1.100000e+07
# Name: last_price, dtype: float64

# %%
# а ящик такой

filtered_data.boxplot(column='last_price', figsize=(3,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод:**
# Задание сформулировано как "Уберите **редкие и выбивающиеся** значения". Возникает вопрос, что в этом случае считать выбивающимися значениями? Как я уже описал в промежуточном итоге, самые дорогие объекты это не выбросы, а вполне реальные квартиры. Поэтому, я считаю просто отсечь все сверхдорогие объекты не самым удачным вариантом. На мой взгляд, их лучше выделить в отдельный датафрейм и работать с ним отдельно. Массовые квартиры отдельно, всякий делюкс - отдельно, чтобы выдающие значения не искажали среднее и медиану обычных квартир. Далее я буду использовать отфильтрованный датафрйм без выдающихся значений.

# %% [markdown]
# #### Аномалии в `ceiling_height`

# %%
# вспомним, о чём речь

data['ceiling_height'].describe()
# Out:
# count    23592.000000
# mean         2.739605
# std          0.759820
# min          1.200000
# 25%          2.600000
# 50%          2.700000
# 75%          2.700000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
# есть какие-то башни (32 метра), посмотрим на все объекты, где высота выше 5 м

data.query('ceiling_height > 5').sort_values(by='ceiling_height')
# Out:
#         last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 464     66571000.0         280           2015-06-11      6             5.2
# 12628    3900000.0          50           2018-03-29      1             5.3
# 1026   155000000.0         310           2018-10-12      5             5.3
# 7578    38000000.0         143           2017-11-02      3             5.5
# 21227    8200000.0          71           2017-07-21      0             5.8
# 20264  119000000.0         188           2017-07-10      4             6.0
# 17442    5350000.0          54           2015-06-16      2             8.0
# 15743    5600000.0          67           2016-11-11      3             8.0
# 3474     1400000.0          30           2018-03-16      1             8.0
# 5863     5650000.0          45           2018-08-15      1             8.3
# 22309    5300000.0          45           2017-09-30      1            10.3
# ...

# %% [markdown]
# Судя по другим значениям объектов с 30-метровыми  потолками (цене, площади) это обычные квартиры с потолками от 2 до 4 метров. Двузначные значения, скорее всего, получились из-за пропуска запятой. Разделим эти значения на 10.

# %%
# создаём отфильтрованный список

index_list = data.query('ceiling_height > 19 and ceiling_height < 35').index

# %%
# проверка

index_list
# Out:
# Int64Index([  355,  3148,  4643,  4876,  5076,  5246,  5669,  5807,  6246,
#              9379, 10773, 11285, 14382, 17496, 17857, 18545, 20478, 20507,
#             21377, 21824, 22336, 22938],
#            dtype='int64')

# %%
# выводим значения

data.loc[index_list]['ceiling_height']
# Out:
# 355      25.0
# 3148     32.0
# 4643     25.0
# 4876     27.0
# 5076     24.0
# 5246     27.0
# 5669     26.0
# 5807     27.0
# 6246     25.0
# 9379     25.0
# 10773    27.0
# 11285    25.0
# 14382    25.0
# 17496    20.0
# 17857    27.0
# 18545    25.0
# 20478    27.0
# 20507    22.6
# 21377    27.5
# 21824    27.0
# 22336    32.0
# 22938    27.0
# Name: ceiling_height, dtype: float64

# %%
# делим на 10

data.loc[index_list, 'ceiling_height'] = data.loc[index_list, 'ceiling_height'] / 10

# %%
# теперь нормальная высота потолков

data.loc[index_list]['ceiling_height']
# Out:
# 355      2.50
# 3148     3.20
# 4643     2.50
# 4876     2.70
# 5076     2.40
# 5246     2.70
# 5669     2.60
# 5807     2.70
# 6246     2.50
# 9379     2.50
# 10773    2.70
# 11285    2.50
# 14382    2.50
# 17496    2.00
# 17857    2.70
# 18545    2.50
# 20478    2.70
# 20507    2.26
# 21377    2.75
# 21824    2.70
# 22336    3.20
# 22938    2.70
# Name: ceiling_height, dtype: float64

# %%
# отфильтруем и очень небольшие значения

index_list = data.query('ceiling_height > 35 or ceiling_height < 1.9 or 7 < ceiling_height < 19').index

# %%
# смотрим результат

data.loc[index_list, 'ceiling_height']
# Out:
# 3474      8.00
# 5712      1.20
# 5863      8.30
# 15061    14.00
# 15743     8.00
# 16934     1.75
# 17442     8.00
# 22309    10.30
# Name: ceiling_height, dtype: float64

# %%
display("Количество строк перед удалением", len(data))
# Out:
# 'Количество строк перед удалением'
# 23592

# %%
# удаляем строки и починим индексы

data.drop(index_list, inplace=True, axis=0)
data.reset_index(inplace=True, drop=True)

# %%
# проверка

display("Количество строк после удаления", len(data))
# Out:
# 'Количество строк после удаления'
# 23584

# %%
# все значения адекватны

data['ceiling_height'].describe()
# Out:
# count    23584.000000
# mean         2.716063
# std          0.217841
# min          2.000000
# 25%          2.600000
# 50%          2.700000
# 75%          2.700000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# ### Задача: Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость цены от площади

# %%
# посчитаем корреляцию

filtered_data['last_price'].corr(filtered_data['total_area'])
# Out:
# 0.6844917613022197

# %%
# построим график

filtered_data.plot(x='total_area', y='last_price', kind='scatter', grid=True, figsize=(10,15), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# **Вывод:** Корреляция, как и ожидалось, есть, чем больше площадь, тем цена выше. Но неожиданно она оказалась небольшой.

# %% [markdown]
# #### Зависимость цены от количества комнат

# %%
# считаем корреляцию

filtered_data['last_price'].corr(filtered_data['rooms'])
# Out:
# 0.4466996175591148

# %%
# строим график

filtered_data.plot(x='rooms', y='last_price', kind='scatter', grid=True, figsize=(16,7), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# **Вывод:** Зависимость от количества комнат ещё ниже, чем от площади. В целом цена возрастает до параметра 3 комнат, после корреляция становится менее выраженной.

# %% [markdown]
# #### Зависимость цены от удалённости от центра

# %%
# считаем корреляцию, предварительно исключив нетипичные значения, которые мы ввели ранее

center_nearest = filtered_data.query('cityCenters_nearest != -1')
center_nearest['last_price'].corr(center_nearest['cityCenters_nearest'])
# Out:
# -0.34000662894805217

# %%
# строим график

center_nearest.plot(x='cityCenters_nearest', y='last_price', kind='scatter', grid=True, figsize=(10,15), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest', ylabel='last_price'>

# %% [markdown]
# **Вывод:** Коэффициент отрицательный на этот раз, но в целом правило чем ближе к центру, тем дороже, работает. С другой стороны, новые дорогие ЖК строят не в центре, потому что там просто места уже нет, поэтому даже на удалении от центра есть высокие цены.

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
# сначала посчитаем среднюю цену по каждому типу категории этажей

floor_category_mean = data.groupby('floor_category')['last_price'].mean()

# %%
# построим график

floor_category_mean.plot(x='floor_category', y='floor_category_mean', kind='bar', grid=True, figsize=(6,5))
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# **Вывод:** Ожидаемо первый этаж наименее привлекателен, поэтому самый дешёвый. Последний этаж немного обогнал все остальные, возможно, молодёжи нравится вид с высоты птичьего полёта из окна. Да и шума и пыли там меньше.

# %% [markdown]
# #### Зависимость цены от даты размещения: дня недели, месяца и года.

# %%
# построим матрицу

pd.plotting.scatter_matrix(filtered_data[['expos_weekday','expos_month','expos_year','last_price']], figsize=(14,14))
# Out:
# array([[<AxesSubplot:xlabel='expos_weekday', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_weekday'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_month'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_year'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='last_price'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='last_price'>,
# ...

# %% [markdown]
# **Вывод:**
#  - Наиболее дешёвые варианты пришлись на выходные
#  - Самые дорогие квартиры высталены в декабре и январе, самые дешёвые в мае
#  - Цена уверенно растёт каждый год, но самая высокая была в 2018 году

# %% [markdown]
# ### Задача: Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
# сгруппируем по имени города и цене

top_towns_by_count = filtered_data.groupby('locality_name')['price_per_meter'].agg(
                                                            ['count', 'mean']
                                                            ).sort_values(
                                                            by='count', ascending=False
                                                            ).head(10)

# %%
top_towns_by_count
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    13460  105032.156761
# посёлок Мурино       520   85700.542308
# посёлок Шушары       439   78554.922551
# Всеволожск           397   67207.040302
# Пушкин               337  100196.777448
# Колпино              336   75209.994048
# посёлок Парголово    327   90177.721713
# Гатчина              305   68400.190164
# деревня Кудрово      298   92446.325503
# Выборг               236   57944.872881

# %% [markdown]
# **Вывод:** Города отфильтрованы, средняя цена кв.м посчитана. Самая высокая стоимость жилья, конечно, в СПб, а самая низкая в Выборге.

# %% [markdown]
# ### Задача: Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
# фильтруем по городу и без нетипичных значений

spb_flats = filtered_data.query('locality_name == "Санкт-Петербург" & cityCenters_nearest != -1')

# %%
# собираем датафрейм с нужными столбцами

spb_flats_price = spb_flats.loc[:, ('locality_name', 'cityCenters_nearest','last_price')]

# %%
# любуемся, т.е. проверяем

spb_flats_price.head()
# Out:
#       locality_name  cityCenters_nearest  last_price
# 2   Санкт-Петербург              13933.0   5196000.0
# 4   Санкт-Петербург               8098.0  10000000.0
# 7   Санкт-Петербург              11634.0   7915000.0
# 9   Санкт-Петербург              15008.0   5400000.0
# 10  Санкт-Петербург              13878.0   5050000.0

# %%
# переводим расстояние в км и округляем

spb_flats_price['cityCenters_nearest'] = (spb_flats_price['cityCenters_nearest']/1000).astype('int')

# %%
# проверяем

spb_flats_price.head()
# Out:
#       locality_name  cityCenters_nearest  last_price
# 2   Санкт-Петербург                   13   5196000.0
# 4   Санкт-Петербург                    8  10000000.0
# 7   Санкт-Петербург                   11   7915000.0
# 9   Санкт-Петербург                   15   5400000.0
# 10  Санкт-Петербург                   13   5050000.0

# %%
# переводим цену в млн

spb_flats_price['last_price'] = spb_flats_price['last_price']/1000000

# %%
# проверяем

spb_flats_price.head()
# Out:
#       locality_name  cityCenters_nearest  last_price
# 2   Санкт-Петербург                   13       5.196
# 4   Санкт-Петербург                    8      10.000
# 7   Санкт-Петербург                   11       7.915
# 9   Санкт-Петербург                   15       5.400
# 10  Санкт-Петербург                   13       5.050

# %%
# создаём сводную таблицу

spb_flats_price_pivot = spb_flats_price.pivot_table(index='cityCenters_nearest',
                                                    values='last_price',
                                                    aggfunc=('mean'))

# %%
# проверяем

spb_flats_price_pivot.head()
# Out:
#                      last_price
# cityCenters_nearest
# 0                      7.942211
# 1                      7.803371
# 2                      7.504674
# 3                      7.249344
# 4                      7.501251

# %%
# строим график

spb_flats_price_pivot.plot(kind='bar', figsize=(16,7), grid=True)
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest'>

# %% [markdown]
# **Вывод:** Нет какого-либо резкого и однозначного скачка цены, что подтверждает размытость этого самого "центра" в реальности. Кроме того, по мере разрастания города вширь и сам центр тоже может меняться если и не где-то на бумаге, то в представлении людей.
# Но опираясь на этот график, будем считать цетром всё, что находится в 6 км включительно.

# %% [markdown]
# ### Задание: Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
# выделим квартиры в центре СПБ, ограничив значением в 6 км

spb_flat_center = spb_flats.query('cityCenters_nearest != -1')
spb_flat_center['cityCenters_nearest'] = (spb_flats['cityCenters_nearest']/1000).round().astype('int')
spb_flat_center = spb_flat_center.query('cityCenters_nearest < 6')

# %%
spb_flat_center.head()
# Out:
#      last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 24    6500000.0          97           2015-10-31      2            2.70
# 61    7990000.0          74           2017-08-24      2            2.70
# 99    9600000.0          90           2017-09-26      4            2.70
# 136   6500000.0          52           2018-08-01      2            3.45
# 138   4800000.0          40           2017-11-18      2            2.70
#
#      floors_total  living_area  floor  is_apartment  studio  ...  \
# 24              3         46.5      1         False   False  ...
# 61              4         43.0      4         False   False  ...
# 99              5         67.0      2         False   False  ...
# 136             6         25.6      2         False   False  ...
# 138             3         29.0      2         False   False  ...
#
#      ponds_around3000  ponds_nearest  days_exposition price_per_meter  \
# ...

# %% [markdown]
# #### Изучим площадь

# %% [markdown]
# Для наглядности тут же будем дублировать соответствующий график по общей выборке.

# %%
# площадь по центру Питера

spb_flat_center['total_area'].plot(kind='hist', figsize=(9,5), grid=True, title='СПб центр', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'СПб центр'}, ylabel='Frequency'>

# %%
# площадь по общей выборке

filtered_data['total_area'].plot(kind='hist', figsize=(9,5), grid=True, title='Общая выборка', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'Общая выборка'}, ylabel='Frequency'>

# %% [markdown]
# #### Изучим цену

# %%
spb_flat_center['last_price'].plot(kind='hist', figsize=(9,5), grid=True, title='СПб центр', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'СПб центр'}, ylabel='Frequency'>

# %%
filtered_data['last_price'].plot(kind='hist', figsize=(9,5), grid=True, title='Общая выборка', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'Общая выборка'}, ylabel='Frequency'>

# %% [markdown]
# #### Изучим количество комнат

# %%
spb_flat_center['rooms'].plot(kind='hist', figsize=(9,5), grid=True, title='СПб центр', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'СПб центр'}, ylabel='Frequency'>

# %%
filtered_data['rooms'].plot(kind='hist', figsize=(9,5), grid=True, title='Общая выборка', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'Общая выборка'}, ylabel='Frequency'>

# %% [markdown]
# #### Изучим высоту потолков

# %%
spb_flat_center['ceiling_height'].plot(kind='hist', figsize=(10,5), grid=True, title='СПб центр', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'СПб центр'}, ylabel='Frequency'>

# %%
filtered_data['ceiling_height'].plot(kind='hist', figsize=(10,5), grid=True, title='Общая выборка', legend=True, bins=30)
# Out:
# <AxesSubplot:title={'center':'Общая выборка'}, ylabel='Frequency'>

# %% [markdown]
# **Новый вывод:**
#  - Площадь квартир в центре ожидаемо больше, но ненамного (по-прежнему актуально)
#  - Цена естественно и существенно больше; (тоже актуально, причём отчётливо стали видны несколько новых пиков)
#  - По количеству комнат ситуация помнялась, в расширенном центре лидерами стали двухкомнатные квартиры (были 2-х)
#  - А высота потолков оказалась одинаковая (тоже не изменилась).

# %% [markdown]
# #### Оценим, как число комнат влияет на стоимость квартиры

# %%
spb_flat_center['last_price'].corr(spb_flat_center['rooms'])
# Out:
# 0.4835539459816235

# %% [markdown]
# Предыдущее значение 0.5944733419741172. Практически не изменилось

# %%
spb_flat_center.plot(x='rooms', y='last_price', kind='scatter', grid=True, figsize=(5,8), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# #### Оценим, как этаж влияет на стоимость квартиры

# %%
spb_flat_center['last_price'].corr(spb_flat_center['floor'])
# Out:
# 0.11460582846440343

# %% [markdown]
# Старое значение 0.07511964543418495. Теперь этаж влияет заметнее

# %%
spb_flat_center.plot(x='floor', y='last_price', kind='scatter', grid=True, figsize=(5,8), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='floor', ylabel='last_price'>

# %% [markdown]
# #### Оценим, как удалённость от центра влияет на стоимость квартиры

# %%
spb_flat_center['last_price'].corr(spb_flat_center['cityCenters_nearest'])
# Out:
# -0.05326870229748612

# %% [markdown]
# Предыдущее значение 0.030471358290318107. А тут корреляция вообще стала отрицательной, что подтверждает мою мысль о том, что новые дорогие квартиры строят не в центре, что и находит отражение в данных

# %%
spb_flat_center.plot(x='cityCenters_nearest', y='last_price', kind='scatter', grid=True, figsize=(5,8), alpha=0.5)
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest', ylabel='last_price'>

# %% [markdown]
# #### Оценим, как дата размещения влияет на стоимость квартиры

# %%
pd.plotting.scatter_matrix(spb_flat_center[['expos_weekday','expos_month','expos_year','last_price']], figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='expos_weekday', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_weekday'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_weekday'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_month'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_month'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='expos_year', ylabel='expos_year'>,
#         <AxesSubplot:xlabel='last_price', ylabel='expos_year'>],
#        [<AxesSubplot:xlabel='expos_weekday', ylabel='last_price'>,
#         <AxesSubplot:xlabel='expos_month', ylabel='last_price'>,
# ...

# %% [markdown]
# **Вывод по-прежнему актуален:**
# В этом случае выводы совпадают с общими:
# - всё так же самые дешёвые предложения на выходных,
# - декабрь и январь самые "дорогие" месяцы,
# - самые дорогие квартиры в 2017 и 2018 годах.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# На этот раз нам достались достаточно "грязные" данные, было много пропусков, артефактов, аномальных значений. Пришлось проходить почти по каждому столбцу, в итоге предобработка заняла едва ли не половину всего времени выполнения проекта. В таких случаях лучше сразу обращать внимание на проблемы ответственных лиц.
# Тем не менее, данные были приведены в приемлемый вид, все посталевленные задачи выполнены, а цель достигнута. Мы определили параметры и закономерности, с помощью которых можно будет выстраивать автоматизированную систему оценки.
# По ходу выполнения проекта я старался максимально подробно описывать свою логику и замечания, после каждого пункта подводя итог.
# В целом очевидные закономерности рынка недвижимости нашли своё подтверждение: квартиры в центре дороже, как и квартиры с большой площадью. С другой стороны, были выявлены интересные закономерности, вроде той, что объявления выходных дней были самыми "дешёвыми".
# На мой взгляд, это логично, если учитывать, что рынок недвижимости огромный, имеет множество метрик, характеристик. Его можно рассматривать с разных сторон и получать разные, иногда, казалось бы, необъяснимые выводы и закономерности. Поэтому построение автоматизированной системы оценки недвижимости - амбициозная и трудоёмкая задача, но, уверен, посильная.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
